# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df["TotalAmount"] = df["Quantity"] * df["UnitPrice"]

# %%
country_sales = df.groupby("Country")["TotalAmount"].sum()

country_sales.sort_values(
    ascending=False
).head(5).plot(kind="bar")

plt.title("Top 5 Countries by Sales")
plt.xlabel("Country")
plt.ylabel("Sales")
plt.show()

# %%
df["InvoiceDate"] = pd.to_datetime(df["InvoiceDate"])

df["Month"] = df["InvoiceDate"].dt.month

df["TotalAmount"] = df["Quantity"] * df["UnitPrice"]

monthly_sales = df.groupby("Month")["TotalAmount"].sum()

monthly_sales.plot(kind="line", marker="o")

plt.title("Monthly Sales Trend")
plt.xlabel("Month")
plt.ylabel("Sales")

plt.show()

# %%
top10 = customer.sort_values(
    by="TotalAmount",
    ascending=False
).head(10)

top10.plot(
    x="CustomerID",
    y="TotalAmount",
    kind="bar"
)

plt.title("Top 10 Customers by Spending")
plt.xlabel("Customer ID")
plt.ylabel("Total Amount")

plt.show()

# %%
import pandas as pd

df = pd.read_csv("Online_Retail.csv")

df["TotalAmount"] = df["Quantity"] * df["UnitPrice"]

cust_id = float(input("Enter Customer ID: "))

result = df[df["CustomerID"] == cust_id]

if len(result) > 0:

    spent = result["TotalAmount"].sum()

    print("Total Spent =", spent)

    print("Expected Purchase =", spent * 1.1)

else:

    print("Customer Not Found")
# Out:
# Total Spent = 5288.630000000001
# Expected Purchase = 5817.493000000001

# %%
import pandas as pd

df = pd.read_csv("Online_Retail.csv")

df["TotalAmount"] = df["Quantity"] * df["UnitPrice"]

cust_id = float(input("Enter Customer ID: "))

result = df[df["CustomerID"] == cust_id]

if len(result) > 0:

    spent = result["TotalAmount"].sum()

    print("Total Spent =", spent)

    print("Expected Purchase =", spent * 1.1)

else:

    print("Customer Not Found")
# Out:
# Total Spent = 5288.630000000001
# Expected Purchase = 5817.493000000001

# %%
import pandas as pd

df = pd.read_csv("Online_Retail.csv")

df["TotalAmount"] = df["Quantity"] * df["UnitPrice"]

cust_id = float(input("Enter Customer ID: "))

result = df[df["CustomerID"] == cust_id]

if len(result) > 0:

    spent = result["TotalAmount"].sum()

    if spent >= 5000:
        segment = "Premium Customer"
    elif spent >= 1000:
        segment = "Regular Customer"
    else:
        segment = "Low Value Customer"

    print("Segment =", segment)
    print("Total Spent =", spent)
    print("Expected Purchase =", spent * 1.1)

else:
    print("Customer Not Found")
# Out:
# Segment = Premium Customer
# Total Spent = 5288.630000000001
# Expected Purchase = 5817.493000000001
